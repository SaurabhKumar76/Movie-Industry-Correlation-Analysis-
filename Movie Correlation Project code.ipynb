# %%
# Import libaries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# Read in the data
df_movies = pd.read_csv("movies.csv")

# %%
df_movies
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_movies['year'].value_counts()
# Out:
# year
# 2000    200
# 2009    200
# 2002    200
# 2003    200
# 2004    200
# 2005    200
# 2006    200
# 2007    200
# 2008    200
# 2010    200
# 2019    200
# 2011    200
# 2012    200
# 2013    200
# 2014    200
# 2015    200
# 2016    200
# 2017    200
# 2001    200
# 1999    200
# 1990    200
# 1991    200
# 1985    200
# 1986    200
# 1987    200
# 1988    200
# 1989    200
# 1998    200
# 2018    200
# 1992    200
# 1993    200
# 1994    200
# 1995    200
# 1996    200
# 1997    200
# 1984    168
# 1983    144
# 1982    126
# 1981    113
# 1980     92
# 2020     25
# Name: count, dtype: int64

# %%
df_movies.shape
# Out:
# (7668, 15)

# %%
df_movies.sort_values('budget')
# Out:
#                              name     rating   genre  year  \
# 471   A Polish Vampire in Burbank  Not Rated  Comedy  1983
# 7658    Black Wall Street Burning          R   Drama  2020
# 3318                    Following          R   Crime  1998
# 2093                  El Mariachi          R  Action  1992
# 4507                       Primer      PG-13   Drama  2004
# ...                           ...        ...     ...   ...
# 7657                         Leap        NaN   Drama  2020
# 7659                    I Am Fear  Not Rated  Horror  2020
# 7660             Aloha Surf Hotel        NaN  Comedy  2020
# 7664                  Dream Round        NaN  Comedy  2020
# 7667                    Tee em el        NaN  Horror  2020
#
#                                 released  score     votes            director  \
# 471     October 31, 1983 (United States)    5.0     275.0          Mark Pirro
# 7658    February 7, 2020 (United States)    6.6      35.0        Marcus Brown
# ...

# %%
df_movies.value_counts('budget')
# Out:
# budget
# 20000000.0     233
# 30000000.0     229
# 25000000.0     211
# 10000000.0     208
# 15000000.0     204
#               ...
# 15100000.0       1
# 15600000.0       1
# 15700000.0       1
# 16200000.0       1
# 356000000.0      1
# Name: count, Length: 413, dtype: int64

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Let's see if there is any missing data
for col in df_movies.columns:
    pct_missing = np.mean(df_movies[col].isnull())
    print("{} - {}%".format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df_movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df_movies['budget'] = df_movies['budget'].astype('int64')
df_movies['gross'] = df_movies['gross'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_movies['budget'] = df_movies['budget'].astype('int64')
#       2 df_movies['gross'] = df_movies['gross'].astype('int64')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df_movies['budget'].value_counts()
# Out:
# budget
# 20000000.0    233
# 30000000.0    229
# 25000000.0    211
# 10000000.0    208
# 15000000.0    204
#              ...
# 34200000.0      1
# 30000.0         1
# 29750000.0      1
# 5250000.0       1
# 58750.0         1
# Name: count, Length: 413, dtype: int64

# %%
df_movies = df_movies.dropna()

# %%
df_movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
for col in df_movies.columns:
    pct_missing = np.mean(df_movies[col].isnull())
    print("{} - {}%".format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
df_movies = df_movies.copy()

# %%
df_movies['budget'] = df_movies['budget'].astype('int64')
df_movies['gross'] = df_movies['gross'].astype('int64')

# %%
df_movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df_movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df_movies['released']
# Out:
# 0           June 13, 1980 (United States)
# 1            July 2, 1980 (United States)
# 2           June 20, 1980 (United States)
# 3            July 2, 1980 (United States)
# 4           July 25, 1980 (United States)
#                       ...
# 7648     January 17, 2020 (United States)
# 7649    February 14, 2020 (United States)
# 7650     January 17, 2020 (United States)
# 7651    February 21, 2020 (United States)
# 7652      August 28, 2020 (United States)
# Name: released, Length: 5421, dtype: object

# %%
df_movies.shape
# Out:
# (5421, 15)

# %%
df_movies.tail()
# Out:
#                       name     rating      genre  year  \
# 7648     Bad Boys for Life          R     Action  2020
# 7649    Sonic the Hedgehog         PG     Action  2020
# 7650              Dolittle         PG  Adventure  2020
# 7651  The Call of the Wild         PG  Adventure  2020
# 7652     The Eight Hundred  Not Rated     Action  2020
#
#                                released  score     votes        director  \
# 7648   January 17, 2020 (United States)    6.6  140000.0    Adil El Arbi
# 7649  February 14, 2020 (United States)    6.5  102000.0     Jeff Fowler
# 7650   January 17, 2020 (United States)    5.6   53000.0  Stephen Gaghan
# 7651  February 21, 2020 (United States)    6.8   42000.0   Chris Sanders
# 7652    August 28, 2020 (United States)    6.8    3700.0         Hu Guan
#
#               writer               star        country     budget      gross  \
# 7648     Peter Craig         Will Smith  United States   90000000  426505244
# ...

# %%
df_movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df_movies[['name','gross']].sort_values('gross')
# Out:
#                                             name       gross
# 3203                                  Trojan War         309
# 272                                     Parasite        2270
# 3681                                Ginger Snaps        2554
# 2434                  Philadelphia Experiment II        2970
# 5640                                 Tanner Hall        5073
# ...                                          ...         ...
# 7244                      Avengers: Infinity War  2048359754
# 6663  Star Wars: Episode VII - The Force Awakens  2069521700
# 3045                                     Titanic  2201647264
# 7445                           Avengers: Endgame  2797501328
# 5445                                      Avatar  2847246203
#
# [5421 rows x 2 columns]

# %%
df_movies[['name','gross']].sort_values('gross', ascending = False)
# Out:
#                                             name       gross
# 5445                                      Avatar  2847246203
# 7445                           Avengers: Endgame  2797501328
# 3045                                     Titanic  2201647264
# 6663  Star Wars: Episode VII - The Force Awakens  2069521700
# 7244                      Avengers: Infinity War  2048359754
# ...                                          ...         ...
# 5640                                 Tanner Hall        5073
# 2434                  Philadelphia Experiment II        2970
# 3681                                Ginger Snaps        2554
# 272                                     Parasite        2270
# 3203                                  Trojan War         309
#
# [5421 rows x 2 columns]

# %%
df_movies.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_movies.head()
#
# NameError: name 'df_movies' is not defined

# %%
df_movies.shape
# Out:
# (5421, 15)

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_movies['company'].sort_values(ascending = False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 2929                          1492 Pictures
# 3525                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 5421, dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df_movies['company'].sort_values(ascending = False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 352                                      Zoetrope Studios
# 724                                      Zoetrope Studios
# 332                                      Zoetrope Studios
# 520                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 4297                              Zentropa Entertainments
# 5471                              Zentropa Entertainments
# 3698                              Zentropa Entertainments
# ...

# %%
# Drop Duplicates
df_movies['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
df_movies[['name', 'budget']].sort_values(by = 'budget', ascending = False)
# Out:
#                                                    name       budget
# 7445                                  Avengers: Endgame  356000000.0
# 7244                             Avengers: Infinity War  321000000.0
# 7075            Star Wars: Episode VIII - The Last Jedi  317000000.0
# 7066                                     Justice League  300000000.0
# 5060           Pirates of the Caribbean: at World's End  300000000.0
# 7463      Star Wars: Episode IX - The Rise of Skywalker  275000000.0
# 7261                            Solo: A Star Wars Story  275000000.0
# 4870                                   Superman Returns  270000000.0
# 7480                                      The Lion King  260000000.0
# 5658                                            Tangled  260000000.0
# 5057                                       Spider-Man 3  258000000.0
# 5451             Harry Potter and the Half-Blood Prince  250000000.0
# 6846                         Captain America: Civil War  250000000.0
# ...

# %%
plt.scatter(x = df_movies['budget'], y = df_movies['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for the film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Plot budget vs gross using seaborn
sns.regplot(x = 'budget', y = 'gross', data = df_movies)
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
sns.regplot(x = 'budget', y = 'gross', data = df_movies, scatter_kws = {'color':'red'}, line_kws = {'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df_movies.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5421.000000  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03
# mean   2001.661317     6.392455  1.150661e+05  3.600917e+07  1.032297e+08
# std      10.540908     0.962730  1.844073e+05  4.157337e+07  1.873027e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.073640e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.180000e+07  3.686941e+07
# 75%    2011.000000     7.100000  1.290000e+05  4.500000e+07  1.124625e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  5421.000000
# mean    108.152739
# std      18.115698
# min      63.000000
# 25%      95.000000
# 50%     105.000000
# 75%     118.000000
# max     271.000000

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_movies.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_movies.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df_movies.corr(numeric_only = True)

# Result - High correlation between budget and gross
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df_movies.corr(method = 'kendall', numeric_only = True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
df_movies.corr(method = 'spearman', numeric_only = True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
correlation_matrix = df_movies.corr(numeric_only = True)

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_movies[['name','runtime']].sort_values('runtime',ascending = False)
# Out:
#                                                    name  runtime
# 2280                                         Gettysburg    271.0
# 2888                                             Hamlet    242.0
# 479                         Once Upon a Time in America    229.0
# 21                                        Heaven's Gate    219.0
# 4343                                  Gods and Generals    219.0
# 3989                        Kabhi Khushi Kabhie Gham...    210.0
# 7465                                       The Irishman    209.0
# 2082                                          Malcolm X    202.0
# 4245      The Lord of the Rings: The Return of the King    201.0
# 2247                                   Schindler's List    195.0
# 115                                                Reds    195.0
# 3045                                            Titanic    194.0
# 345                                     The Right Stuff    193.0
# ...

# %%
df_movies_numerized = df_movies.copy()

# %%
for col_name in df_movies_numerized.columns:
    if(df_movies_numerized[col_name].dtype == 'object'):
        df_movies_numerized[col_name] = df_movies_numerized[col_name].astype('category')
        df_movies_numerized[col_name] = df_movies_numerized[col_name].cat.codes

# %%
df_movies_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country      budget        gross  company  runtime
# 0   699       46  19000000.0   46998772.0     1426    146.0
# 1   214       47   4500000.0   58853106.0      452    104.0
# 2  1157       47  18000000.0  538375067.0      945    124.0
# 3  1474       47   3500000.0   83453539.0     1108     88.0
# 4   271       47   6000000.0   39846344.0     1083     98.0

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_movies = pd.read_csv("movies.csv")

# %%
df_movies = df_movies.dropna()

# %%
df_movies_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country      budget        gross  company  runtime
# 0   699       46  19000000.0   46998772.0     1426    146.0
# 1   214       47   4500000.0   58853106.0      452    104.0
# 2  1157       47  18000000.0  538375067.0      945    124.0
# 3  1474       47   3500000.0   83453539.0     1108     88.0
# 4   271       47   6000000.0   39846344.0     1083     98.0

# %%
df_movies
# Out:
#                                                    name     rating      genre  \
# 0                                           The Shining          R      Drama
# 1                                       The Blue Lagoon          R  Adventure
# 2        Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                             Airplane!         PG     Comedy
# 4                                            Caddyshack          R     Comedy
# 5                                       Friday the 13th          R     Horror
# 6                                    The Blues Brothers          R     Action
# 7                                           Raging Bull          R  Biography
# 8                                           Superman II         PG     Action
# 9                                       The Long Riders          R  Biography
# 10                                Any Which Way You Can         PG     Action
# ...

# %%
df_movies.shape
# Out:
# (5421, 15)

# %%
df_movies_numerized.shape
# Out:
# (5421, 15)

# %%
df_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_movies_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country      budget        gross  company  runtime
# 0   699       46  19000000.0   46998772.0     1426    146.0
# 1   214       47   4500000.0   58853106.0      452    104.0
# 2  1157       47  18000000.0  538375067.0      945    124.0
# 3  1474       47   3500000.0   83453539.0     1108     88.0
# 4   271       47   6000000.0   39846344.0     1083     98.0

# %%
correlation_matrix = df_movies_numerized.corr(numeric_only = True)

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_matrix = df_movies_numerized.corr(numeric_only = True)

corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.029234
#           genre       0.010996
#           year        0.025542
#           released   -0.006152
#           score       0.014450
#           votes       0.012615
#           director    0.015246
#           writer      0.012880
#           star       -0.006882
#           country    -0.025490
#           budget      0.023392
#           gross       0.005639
#           company     0.021697
#           runtime     0.010850
# rating    name       -0.029234
#           rating      1.000000
#           genre       0.147796
#           year        0.019499
#           released    0.018083
#           score       0.065983
#           votes       0.006031
#           director    0.014656
#           writer     -0.003149
#           star        0.009196
#           country     0.008230
#           budget     -0.203946
#           gross      -0.181906
#           company    -0.092357
#           runtime     0.140792
# ...

# %%
sorted_pairs = corr_pairs.sort_values(ascending = False)
sorted_pairs
# Out:
# name      name        1.000000
# rating    rating      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# director  director    1.000000
# runtime   runtime     1.000000
# gross     budget      0.740247
# budget    gross       0.740247
# votes     gross       0.614751
# gross     votes       0.614751
# votes     score       0.474256
# score     votes       0.474256
# budget    votes       0.439675
# votes     budget      0.439675
# runtime   score       0.414068
# score     runtime     0.414068
# runtime   votes       0.352303
# votes     runtime     0.352303
# budget    year        0.327722
# year      budget      0.327722
# runtime   budget      0.318695
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.4]
high_corr
# Out:
# name      name        1.000000
# rating    rating      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# director  director    1.000000
# runtime   runtime     1.000000
# gross     budget      0.740247
# budget    gross       0.740247
# votes     gross       0.614751
# gross     votes       0.614751
# votes     score       0.474256
# score     votes       0.474256
# budget    votes       0.439675
# votes     budget      0.439675
# runtime   score       0.414068
# score     runtime     0.414068
# dtype: float64

# %%
# Votes and budget have high correlation to gross earnings
